# %% [markdown]
# <a href="https://colab.research.google.com/github/smitjiwani/DWM-pynbs/blob/main/dwm-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

n1 = np.array([[3,5,7,8], [3,2,1,3], [2,1,8,4], [5,2,1,8]])
print(n1)
# Out:
# [[3 5 7 8]
#  [3 2 1 3]
#  [2 1 8 4]
#  [5 2 1 8]]

# %%
p1 = pd.DataFrame(n1, columns= ["a", "b", "c", "d"])
p1.index = [1,2,3,4]
p1
# Out:
#    a  b  c  d
# 1  3  5  7  8
# 2  3  2  1  3
# 3  2  1  8  4
# 4  5  2  1  8

# %%
p1.dtypes
# Out:
# a    int64
# b    int64
# c    int64
# d    int64
# dtype: object

# %%
p1['d'][2]= '$3'

# %%
p1.dtypes
# Out:
# a     int64
# b     int64
# c     int64
# d    object
# dtype: object

# %%
p1
# Out:
#    a  b  c   d
# 1  3  5  7   8
# 2  3  2  1  $3
# 3  2  1  8   4
# 4  5  2  1   8

# %%
p1[['a','c']]
# Out:
#    a  c
# 1  3  7
# 2  3  1
# 3  2  8
# 4  5  1

# %%
p1.loc[2:4, :]
# Out:
#    a  b  c   d
# 2  3  2  1  $3
# 3  2  1  8   4
# 4  5  2  1   8

# %%
  p1.loc[[2,4], ['b','d']]
# Out:
#    b   d
# 2  2  $3
# 4  2   8

# %%
p1.loc[2:4, 'b':'d']
# Out:
#    b  c   d
# 2  2  1  $3
# 3  1  8   4
# 4  2  1   8

# %%
p1.iloc[0:3, 1:1+3]
# Out:
#    b  c   d
# 1  5  7   8
# 2  2  1  $3
# 3  1  8   4

# %%
p1.iloc[0:3, 2:2+4]
# Out:
#    c   d
# 1  7   8
# 2  1  $3
# 3  8   4

# %%
p1.iloc[2:3, 1:2] = 45

# %%
p1
# Out:
#    a   b  c   d
# 1  3   5  7   8
# 2  3   2  1  $3
# 3  2  45  8   4
# 4  5   2  1   8

# %%
p1['e']=[4,3,2,1]

# %%
p1
# Out:
#    a   b  c   d
# 1  3   5  7   8
# 2  3   2  1  $3
# 3  2  45  8   4
# 4  5   2  1   8
# e  4   3  2   1

# %%
p1.loc[3, 'a']=22

# %%
p1
# Out:
#     a   b  c   d
# 1   3   5  7   8
# 2   3   2  1  $3
# 3  22  45  8   4
# 4   5   2  1   8
# e   4   3  2   1

# %%
p1['c'][4]= 11
# Out:
# <ipython-input-48-a8815118dc03>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p1['c'][4]= 11

# %%
p1
# Out:
#     a   b   c   d
# 1   3   5   7   8
# 2   3   2   1  $3
# 3  22  45   8   4
# 4   5   2  11   8
# e   4   3   2   1

# %%
p1.iloc[2:2+2, :]
# Out:
#     a   b   c  d
# 3  22  45   8  4
# 4   5   2  11  8

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/heart1.csv')
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.shape
# Out:
# (303, 14)

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
print(df['age'].std())
# Out:
# 9.082100989837857

# %%
print(df['age'].mean() - df['age'].std())
print(df['age'].mean() + df['age'].std())
# Out:
# 45.28423564382551
# 63.44843762350122

# %%
print(df['age'].mean() - 2*df['age'].std())
print(df['age'].mean() + 2*df['age'].std())
# Out:
# 36.202134653987656
# 72.53053861333908

# %%
df['age'].hist()
# Out:
# <Axes: >

# %%
marks = np.array([22,17,28,30,20,26,37,16,26,22,19])

# %%
marks_mean = marks.mean()
marks_mean
# Out:
# 23.90909090909091

# %%
marks_variance = ((marks - marks_mean)**2).mean()
marks_variance
# Out:
# 35.53719008264463

# %%
print(23.0 - 5.96)
print(23.0 + 5.96)
print(23.0 - 2*5.96)
print(23.0 - 2*5.96)
# Out:
# 17.04
# 17.04

# %%
print(df['trtbps'].mean())
print(df['trtbps'].median())
# Out:
# 131.62376237623764
# 130.0

# %%
df['trtbps'].hist()
# Out:
# <Axes: >

# %%
d = pd.DataFrame([1,1,1,1,1,1,9,8,7,10])
d
# Out:
#     0
# 0   1
# 1   1
# 2   1
# 3   1
# 4   1
# 5   1
# 6   9
# 7   8
# 8   7
# 9  10

# %%
print(d.mean())
print(d.median())
# Out:
# 0    4.0
# dtype: float64
# 0    1.0
# dtype: float64

# %%
d[0].hist()
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
print(df['sex'].unique())
print(df['cp'].unique())
print(df['fbs'].unique())
print(df['restecg'].unique())
print(df['exng'].unique())
print(df['thall'].unique())
# Out:
# [1 0]
# [3 2 1 0]
# [1 0]
# [0 1 2]
# [0 1]
# [1 2 3 0]
