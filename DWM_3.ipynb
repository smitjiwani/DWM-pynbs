# %% [markdown]
# <a href="https://colab.research.google.com/github/smitjiwani/DWM-pynbs/blob/main/DWM_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
x = [1,2,3,4,5,6]
y = [10, 50, 100, 80 ,60, 90]
plt.scatter(x,y)
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [10, 50, 100, 80 ,60, 90]
c = ["red", "green", "blue", "black", "brown", "orange"]
plt.scatter(x,y,c=c)
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [10, 50, 100, 80 ,60, 90]
# c = ["red", "green", "blue", "black", "brown", "orange"]
plt.scatter(x,y,c="red")
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [10, 50, 100, 80 ,60, 90]
# c = ["red", "green", "blue", "black", "brown", "orange"]
plt.scatter(x,y,c="black")
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [10, 50, 100, 80 ,60, 90]
size =[10, 100, 20, 90, 50, 70]
c = ["red", "green", "blue", "black", "brown", "orange"]
plt.scatter(x,y,c="blue", s=size)
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [10, 50, 100, 80 ,60, 90]
size =[10, 100, 20, 90, 50, 70]
# c = ["red", "green", "blue", "black", "brown", "orange"]
plt.scatter(x,y,c="blue", s=size, alpha=0.25)
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [10, 50, 100, 80 ,60, 90]
size =[10, 100, 20, 90, 50, 70]
# c = ["red", "green", "blue", "black", "brown", "orange"]
# plt.scatter(x,y,c="blue", s=size)
plt.scatter(x,y,c=size,alpha=1,s=size)
plt.show()

# %%
x = [1,2,3,4,5,6]
y = [10, 50, 100, 80 ,60, 90]
size =[10, 100, 20, 90, 50, 70]
colour = ["red", "green", "blue", "black", "brown", "orange"]
# c = ["red", "green", "blue", "black", "brown", "orange"]
plt.scatter(x,y,c="green", s=size, cmap="virdis")

x = [1,2,3,4,5,6]
y = [100, 70, 10, 50 ,30, 20]
size =[10, 100, 20, 90, 50, 70]
colour = ["red", "green", "blue", "black", "brown", "orange"]
plt.scatter(x,y,c="orange", s=size, alpha=1, cmap="virdis")


plt.show()
# Out:
# <ipython-input-15-24ee7697b9fe>:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y,c="green", s=size, cmap="virdis")
# <ipython-input-15-24ee7697b9fe>:12: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y,c="orange", s=size, alpha=1, cmap="virdis")

# %%
x = [1,2,3,4,5,6]
y = [10, 50, 100, 80 ,60, 90]
size =[10, 100, 20, 90, 50, 70]
colour = ["red", "green", "blue", "black", "brown", "orange"]
# c = ["red", "green", "blue", "black", "brown", "orange"]
plt.scatter(x,y,c="green", s=size, cmap="virdis", label="2019")

x = [1,2,3,4,5,6]
y = [100, 70, 10, 50 ,30, 20]
size =[10, 100, 20, 90, 50, 70]
colour = ["red", "green", "blue", "black", "brown", "orange"]
plt.scatter(x,y,c="orange", s=size, alpha=1, cmap="virdis", label="2019")

plt.legend()
plt.show()
# Out:
# <ipython-input-20-8187b8f11287>:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y,c="green", s=size, cmap="virdis", label="2019")
# <ipython-input-20-8187b8f11287>:12: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y,c="orange", s=size, alpha=1, cmap="virdis", label="2019")

# %%
x = [1,2,3,4,5,6]
y = [10, 50, 100, 80 ,60, 90]
size =[10, 100, 20, 90, 50, 70]
colour = ["red", "green", "blue", "black", "brown", "orange"]
# c = ["red", "green", "blue", "black", "brown", "orange"]
plt.scatter(x,y,c="green", s=size, cmap="virdis", label="2019")

x = [1,2,3,4,5,6]
y = [100, 70, 10, 50 ,30, 20]
size =[10, 100, 20, 90, 50, 70]
colour = ["red", "green", "blue", "black", "brown", "orange"]
plt.scatter(x,y,c="orange", s=size, alpha=1, cmap="virdis", label="2019")

plt.title("Scatter Plot")
plt.legend()
plt.show()
# Out:
# <ipython-input-21-63f04ae91a55>:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y,c="green", s=size, cmap="virdis", label="2019")
# <ipython-input-21-63f04ae91a55>:12: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y,c="orange", s=size, alpha=1, cmap="virdis", label="2019")
